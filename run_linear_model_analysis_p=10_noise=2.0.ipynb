# %%
from run_analysis import run_linear_model_analysis

# %%
ITERATIONS = 1000
TUNE = 1000
N_POST_SAMPLES = 50#100
NUMBER_OF_PREDICTORS = 10
RANDOM_SEED = 3#58

Y_0_1_NOISE = 2.0
LOG_ODDS_NOISE = 2.0

# %%
#N_IN_STUDY = 50
#
#run_linear_model_analysis(
#    iterations=ITERATIONS, 
#    tune=TUNE, 
#    n_post_samples=N_POST_SAMPLES, 
#    n_predictors=NUMBER_OF_PREDICTORS, 
#    n_in_study=N_IN_STUDY,
#    y_0_1_noise = Y_0_1_NOISE,
#    log_odds_noise = LOG_ODDS_NOISE,
#    seed=RANDOM_SEED)

# %%
N_IN_STUDY = 250

run_linear_model_analysis(
    iterations=ITERATIONS, 
    tune=TUNE, 
    n_post_samples=N_POST_SAMPLES, 
    n_predictors=NUMBER_OF_PREDICTORS, 
    n_in_study=N_IN_STUDY,
    y_0_1_noise = Y_0_1_NOISE,
    log_odds_noise = LOG_ODDS_NOISE,
    seed=RANDOM_SEED)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [Beta]
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 20 seconds.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sig, Beta]
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 25 seconds.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sig, Beta]
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 20 seconds.
# 100%|██████████| 50/50 [26:58<00:00, 32.36s/it]
# /Users/omarchavez/UT/CausalDART/run_analysis.py:113: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(3, 2, 3)

# %%
N_IN_STUDY = 500

run_linear_model_analysis(
    iterations=ITERATIONS, 
    tune=TUNE, 
    n_post_samples=N_POST_SAMPLES, 
    n_predictors=NUMBER_OF_PREDICTORS, 
    n_in_study=N_IN_STUDY,
    y_0_1_noise = Y_0_1_NOISE,
    log_odds_noise = LOG_ODDS_NOISE,
    seed = RANDOM_SEED
)
# Out:
# 100%|██████████| 50/50 [28:02<00:00, 33.65s/it]
# /Users/omarchavez/UT/CausalDART/run_analysis.py:113: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(3, 2, 3)

# %%
N_IN_STUDY = 1000

run_linear_model_analysis(
    iterations=ITERATIONS, 
    tune=TUNE, 
    n_post_samples=N_POST_SAMPLES, 
    n_predictors=NUMBER_OF_PREDICTORS, 
    n_in_study=N_IN_STUDY,
    y_0_1_noise = Y_0_1_NOISE,
    log_odds_noise = LOG_ODDS_NOISE,
    seed = RANDOM_SEED
)
# Out:
# 100%|██████████| 50/50 [36:28<00:00, 43.77s/it]
# /Users/omarchavez/UT/CausalDART/run_analysis.py:113: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(3, 2, 3)
